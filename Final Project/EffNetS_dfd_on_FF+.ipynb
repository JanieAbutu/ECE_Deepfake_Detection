# %%
# ================================================================
# CONFIGURATION SECTION
# ================================================================

import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, confusion_matrix, ConfusionMatrixDisplay, classification_report)
import matplotlib.pyplot as plt


import random
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split

import torchvision.transforms as transforms
from torchvision.io import read_image
from torchvision import models

# -----------------------
# REPRODUCIBILITY
# -----------------------
def set_seed(seed=42):
    import random, numpy as np, torch
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

def worker_init(worker_id):
    np.random.seed(42 + worker_id)
    random.seed(42 + worker_id)


# -----------------------
# FILE PATH
# -----------------------
image_root_dir = "/kaggle/input/faceforensics-extracted-dataset-c23/FF++C32-Frames"
ORIGINAL_CSV = "/kaggle/input/faceforensics-extracted-dataset-c23/CSVs/Original.csv"
DEEPFAKES_CSV = "/kaggle/input/faceforensics-extracted-dataset-c23/CSVs/Deepfakes.csv"

# -----------------------
# TRAIN/VAL/TEST SPLITS
# -----------------------
TRAIN_SPLIT = 0.7
VAL_SPLIT = 0.15
TEST_SPLIT = 0.15

# IMAGE PREPROCESSING
BATCH_SIZE = 16
IMAGE_SIZE = (224, 224)
num_workers = 2

# HYPERPARAMETERS
LR = 1e-4
num_epochs = 200
best_val_loss = float('inf')
best_model_path = 'best_model_efficientnet_b7.pth'
patience = 30
epochs_no_improve = 0

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# ================================================================
# BUILD DATAFRAME
# ================================================================
def build_combined_dataframe():
    df_original = pd.read_csv(ORIGINAL_CSV)
    df_deepfakes = pd.read_csv(DEEPFAKES_CSV)

    df = pd.concat([df_original, df_deepfakes], ignore_index=True)

    df['filepath'] = df.apply(
        lambda r: os.path.join(image_root_dir, r['label'], r["filename"]), axis=1
    )

    df['label_id'] = df['label'].map({"Original": 0, "Deepfakes": 1})
    return df

# ================================================================
# DATASET
# ================================================================
class FFDataset(Dataset):
    def __init__(self, dataframe, transform=None):
        self.df = dataframe
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img = read_image(row.filepath).float() / 255.0

        if self.transform:
            img = self.transform(img)

        label = torch.tensor(row["label_id"], dtype=torch.long)
        return img, label

# ================================================================
# TRANSFORMS
# ================================================================
def get_transforms():
    return transforms.Compose([
        transforms.Resize(IMAGE_SIZE),
        transforms.RandomHorizontalFlip(0.5),
        transforms.RandomRotation(5),
        transforms.ColorJitter(0.1, 0.1),
        transforms.Normalize(
            mean=[0.485, 0.456, 0.406], 
            std=[0.229, 0.224, 0.225] 
        )
    ])

# %%
# ================================================================
# DATA LOADING
# ================================================================
df = build_combined_dataframe()
transform = get_transforms()
all_dataset = FFDataset(df, transform=transform)

total_len = len(all_dataset)
train_len = int(TRAIN_SPLIT * total_len)
val_len = int(VAL_SPLIT * total_len)
test_len = int(TEST_SPLIT * total_len)

train_set, val_set, test_set = random_split(
    all_dataset, [train_len, val_len, test_len]
)

train_loader = DataLoader(
    train_set, batch_size=BATCH_SIZE, shuffle=True,
    num_workers=num_workers, worker_init_fn=worker_init, pin_memory=True
)
val_loader = DataLoader(
    val_set, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=num_workers, worker_init_fn=worker_init, pin_memory=True
)
test_loader = DataLoader(
    test_set, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=num_workers, worker_init_fn=worker_init, pin_memory=True
)

print("Train distribution:", np.bincount([y for _, y in train_set]))
print("Val distribution:", np.bincount([y for _, y in val_set]))
print("Test distribution:", np.bincount([y for _, y in test_set]))
# Out:
# Train distribution: [3490 3510]
# Val distribution: [764 736]
# Test distribution: [746 754]

# %%
# ================================================================
# MODEL: EfficientNet-B7 (PRETRAINED)
# ================================================================
class EfficientNetB7Binary(nn.Module):
    def __init__(self):
        super().__init__()
        self.backbone = models.efficientnet_b7(weights="IMAGENET1K_V1")


        in_features = self.backbone.classifier[1].in_features

        self.backbone.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(in_features, 1)  
        )

    def forward(self, x):
        return self.backbone(x)

model = EfficientNetB7Binary().to(DEVICE)
print(model)

optimizer = optim.Adam(model.parameters(), lr=LR)
criterion = nn.BCEWithLogitsLoss()

for name, p in model.named_parameters():
    print(name, p.requires_grad)
# Out:
# EfficientNetB7Binary(
#   (backbone): EfficientNet(
#     (features): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): SiLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#               (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (2): Conv2dNormActivation(
#               (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (2): Conv2dNormActivation(
#               (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.0036363636363636364, mode=row)
#         )
#         (2): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (2): Conv2dNormActivation(
#               (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.007272727272727273, mode=row)
#         )
#         (3): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (2): Conv2dNormActivation(
#               (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.01090909090909091, mode=row)
#         )
#       )
#       (2): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(192, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#               (1): BatchNorm2d(192, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.014545454545454545, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#               (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.01818181818181818, mode=row)
#         )
#         (2): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#               (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.02181818181818182, mode=row)
#         )
#         (3): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#               (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.025454545454545455, mode=row)
#         )
#         (4): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#               (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.02909090909090909, mode=row)
#         )
#         (5): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#               (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.03272727272727273, mode=row)
#         )
#         (6): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#               (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.03636363636363636, mode=row)
#         )
#       )
#       (3): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=288, bias=False)
#               (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(288, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.04, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.04363636363636364, mode=row)
#         )
#         (2): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.04727272727272727, mode=row)
#         )
#         (3): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.05090909090909091, mode=row)
#         )
#         (4): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.05454545454545454, mode=row)
#         )
#         (5): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.05818181818181818, mode=row)
#         )
#         (6): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.06181818181818183, mode=row)
#         )
#       )
#       (4): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.06545454545454546, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.06909090909090909, mode=row)
#         )
#         (2): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.07272727272727272, mode=row)
#         )
#         (3): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.07636363636363637, mode=row)
#         )
#         (4): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.08, mode=row)
#         )
#         (5): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.08363636363636365, mode=row)
#         )
#         (6): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.08727272727272728, mode=row)
#         )
#         (7): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.09090909090909091, mode=row)
#         )
#         (8): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.09454545454545454, mode=row)
#         )
#         (9): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.09818181818181819, mode=row)
#         )
#       )
#       (5): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#               (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(960, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.10181818181818182, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#               (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.10545454545454547, mode=row)
#         )
#         (2): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#               (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.10909090909090909, mode=row)
#         )
#         (3): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#               (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.11272727272727273, mode=row)
#         )
#         (4): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#               (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.11636363636363636, mode=row)
#         )
#         (5): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#               (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.12000000000000001, mode=row)
#         )
#         (6): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#               (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.12363636363636366, mode=row)
#         )
#         (7): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#               (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.12727272727272726, mode=row)
#         )
#         (8): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#               (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.13090909090909092, mode=row)
#         )
#         (9): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
# ...
# backbone.features.4.9.block.1.1.weight True
# backbone.features.4.9.block.1.1.bias True
# backbone.features.4.9.block.2.fc1.weight True
# backbone.features.4.9.block.2.fc1.bias True
# backbone.features.4.9.block.2.fc2.weight True
# backbone.features.4.9.block.2.fc2.bias True
# backbone.features.4.9.block.3.0.weight True
# backbone.features.4.9.block.3.1.weight True
# backbone.features.4.9.block.3.1.bias True
# backbone.features.5.0.block.0.0.weight True
# backbone.features.5.0.block.0.1.weight True
# backbone.features.5.0.block.0.1.bias True
# backbone.features.5.0.block.1.0.weight True
# backbone.features.5.0.block.1.1.weight True
# backbone.features.5.0.block.1.1.bias True
# backbone.features.5.0.block.2.fc1.weight True
# backbone.features.5.0.block.2.fc1.bias True
# backbone.features.5.0.block.2.fc2.weight True
# backbone.features.5.0.block.2.fc2.bias True
# backbone.features.5.0.block.3.0.weight True
# backbone.features.5.0.block.3.1.weight True
# backbone.features.5.0.block.3.1.bias True
# backbone.features.5.1.block.0.0.weight True
# backbone.features.5.1.block.0.1.weight True
# backbone.features.5.1.block.0.1.bias True
# backbone.features.5.1.block.1.0.weight True
# backbone.features.5.1.block.1.1.weight True
# backbone.features.5.1.block.1.1.bias True
# backbone.features.5.1.block.2.fc1.weight True
# backbone.features.5.1.block.2.fc1.bias True
# backbone.features.5.1.block.2.fc2.weight True
# backbone.features.5.1.block.2.fc2.bias True
# backbone.features.5.1.block.3.0.weight True
# backbone.features.5.1.block.3.1.weight True
# backbone.features.5.1.block.3.1.bias True
# backbone.features.5.2.block.0.0.weight True
# backbone.features.5.2.block.0.1.weight True
# backbone.features.5.2.block.0.1.bias True
# backbone.features.5.2.block.1.0.weight True
# backbone.features.5.2.block.1.1.weight True
# backbone.features.5.2.block.1.1.bias True
# backbone.features.5.2.block.2.fc1.weight True
# backbone.features.5.2.block.2.fc1.bias True
# backbone.features.5.2.block.2.fc2.weight True
# backbone.features.5.2.block.2.fc2.bias True
# backbone.features.5.2.block.3.0.weight True
# backbone.features.5.2.block.3.1.weight True
# backbone.features.5.2.block.3.1.bias True
# backbone.features.5.3.block.0.0.weight True
# backbone.features.5.3.block.0.1.weight True
# backbone.features.5.3.block.0.1.bias True
# backbone.features.5.3.block.1.0.weight True
# backbone.features.5.3.block.1.1.weight True
# backbone.features.5.3.block.1.1.bias True
# backbone.features.5.3.block.2.fc1.weight True
# backbone.features.5.3.block.2.fc1.bias True
# backbone.features.5.3.block.2.fc2.weight True
# backbone.features.5.3.block.2.fc2.bias True
# backbone.features.5.3.block.3.0.weight True
# backbone.features.5.3.block.3.1.weight True
# backbone.features.5.3.block.3.1.bias True
# backbone.features.5.4.block.0.0.weight True
# backbone.features.5.4.block.0.1.weight True
# backbone.features.5.4.block.0.1.bias True
# backbone.features.5.4.block.1.0.weight True
# backbone.features.5.4.block.1.1.weight True
# backbone.features.5.4.block.1.1.bias True
# backbone.features.5.4.block.2.fc1.weight True
# backbone.features.5.4.block.2.fc1.bias True
# backbone.features.5.4.block.2.fc2.weight True
# backbone.features.5.4.block.2.fc2.bias True
# backbone.features.5.4.block.3.0.weight True
# backbone.features.5.4.block.3.1.weight True
# backbone.features.5.4.block.3.1.bias True
# backbone.features.5.5.block.0.0.weight True
# backbone.features.5.5.block.0.1.weight True
# backbone.features.5.5.block.0.1.bias True
# backbone.features.5.5.block.1.0.weight True
# backbone.features.5.5.block.1.1.weight True
# backbone.features.5.5.block.1.1.bias True
# backbone.features.5.5.block.2.fc1.weight True
# backbone.features.5.5.block.2.fc1.bias True
# backbone.features.5.5.block.2.fc2.weight True
# backbone.features.5.5.block.2.fc2.bias True
# backbone.features.5.5.block.3.0.weight True
# backbone.features.5.5.block.3.1.weight True
# backbone.features.5.5.block.3.1.bias True
# backbone.features.5.6.block.0.0.weight True
# backbone.features.5.6.block.0.1.weight True
# backbone.features.5.6.block.0.1.bias True
# backbone.features.5.6.block.1.0.weight True
# backbone.features.5.6.block.1.1.weight True
# backbone.features.5.6.block.1.1.bias True
# backbone.features.5.6.block.2.fc1.weight True
# backbone.features.5.6.block.2.fc1.bias True
# backbone.features.5.6.block.2.fc2.weight True
# backbone.features.5.6.block.2.fc2.bias True
# backbone.features.5.6.block.3.0.weight True
# backbone.features.5.6.block.3.1.weight True
# backbone.features.5.6.block.3.1.bias True
# backbone.features.5.7.block.0.0.weight True
# backbone.features.5.7.block.0.1.weight True
# backbone.features.5.7.block.0.1.bias True
# backbone.features.5.7.block.1.0.weight True
# backbone.features.5.7.block.1.1.weight True
# backbone.features.5.7.block.1.1.bias True
# backbone.features.5.7.block.2.fc1.weight True
# backbone.features.5.7.block.2.fc1.bias True
# backbone.features.5.7.block.2.fc2.weight True
# backbone.features.5.7.block.2.fc2.bias True
# backbone.features.5.7.block.3.0.weight True
# backbone.features.5.7.block.3.1.weight True
# backbone.features.5.7.block.3.1.bias True
# backbone.features.5.8.block.0.0.weight True
# backbone.features.5.8.block.0.1.weight True
# backbone.features.5.8.block.0.1.bias True
# backbone.features.5.8.block.1.0.weight True
# backbone.features.5.8.block.1.1.weight True
# backbone.features.5.8.block.1.1.bias True
# backbone.features.5.8.block.2.fc1.weight True
# backbone.features.5.8.block.2.fc1.bias True
# backbone.features.5.8.block.2.fc2.weight True
# backbone.features.5.8.block.2.fc2.bias True
# backbone.features.5.8.block.3.0.weight True
# backbone.features.5.8.block.3.1.weight True
# backbone.features.5.8.block.3.1.bias True
# backbone.features.5.9.block.0.0.weight True
# backbone.features.5.9.block.0.1.weight True
# backbone.features.5.9.block.0.1.bias True
# backbone.features.5.9.block.1.0.weight True
# backbone.features.5.9.block.1.1.weight True
# backbone.features.5.9.block.1.1.bias True
# backbone.features.5.9.block.2.fc1.weight True
# backbone.features.5.9.block.2.fc1.bias True
# backbone.features.5.9.block.2.fc2.weight True
# backbone.features.5.9.block.2.fc2.bias True
# backbone.features.5.9.block.3.0.weight True
# backbone.features.5.9.block.3.1.weight True
# backbone.features.5.9.block.3.1.bias True
# backbone.features.6.0.block.0.0.weight True
# backbone.features.6.0.block.0.1.weight True
# backbone.features.6.0.block.0.1.bias True
# backbone.features.6.0.block.1.0.weight True
# backbone.features.6.0.block.1.1.weight True
# backbone.features.6.0.block.1.1.bias True
# backbone.features.6.0.block.2.fc1.weight True
# backbone.features.6.0.block.2.fc1.bias True
# backbone.features.6.0.block.2.fc2.weight True
# backbone.features.6.0.block.2.fc2.bias True
# backbone.features.6.0.block.3.0.weight True
# backbone.features.6.0.block.3.1.weight True
# backbone.features.6.0.block.3.1.bias True
# backbone.features.6.1.block.0.0.weight True
# backbone.features.6.1.block.0.1.weight True
# backbone.features.6.1.block.0.1.bias True
# backbone.features.6.1.block.1.0.weight True
# backbone.features.6.1.block.1.1.weight True
# backbone.features.6.1.block.1.1.bias True
# backbone.features.6.1.block.2.fc1.weight True
# backbone.features.6.1.block.2.fc1.bias True
# backbone.features.6.1.block.2.fc2.weight True
# backbone.features.6.1.block.2.fc2.bias True
# backbone.features.6.1.block.3.0.weight True
# backbone.features.6.1.block.3.1.weight True
# backbone.features.6.1.block.3.1.bias True
# backbone.features.6.2.block.0.0.weight True
# backbone.features.6.2.block.0.1.weight True
# backbone.features.6.2.block.0.1.bias True
# backbone.features.6.2.block.1.0.weight True
# backbone.features.6.2.block.1.1.weight True
# backbone.features.6.2.block.1.1.bias True
# backbone.features.6.2.block.2.fc1.weight True
# backbone.features.6.2.block.2.fc1.bias True
# backbone.features.6.2.block.2.fc2.weight True
# backbone.features.6.2.block.2.fc2.bias True
# backbone.features.6.2.block.3.0.weight True
# backbone.features.6.2.block.3.1.weight True
# backbone.features.6.2.block.3.1.bias True
# backbone.features.6.3.block.0.0.weight True
# backbone.features.6.3.block.0.1.weight True
# backbone.features.6.3.block.0.1.bias True
# backbone.features.6.3.block.1.0.weight True
# backbone.features.6.3.block.1.1.weight True
# backbone.features.6.3.block.1.1.bias True
# backbone.features.6.3.block.2.fc1.weight True
# backbone.features.6.3.block.2.fc1.bias True
# backbone.features.6.3.block.2.fc2.weight True
# backbone.features.6.3.block.2.fc2.bias True
# backbone.features.6.3.block.3.0.weight True
# backbone.features.6.3.block.3.1.weight True
# backbone.features.6.3.block.3.1.bias True
# backbone.features.6.4.block.0.0.weight True
# backbone.features.6.4.block.0.1.weight True
# backbone.features.6.4.block.0.1.bias True
# backbone.features.6.4.block.1.0.weight True
# backbone.features.6.4.block.1.1.weight True
# backbone.features.6.4.block.1.1.bias True
# backbone.features.6.4.block.2.fc1.weight True
# backbone.features.6.4.block.2.fc1.bias True
# backbone.features.6.4.block.2.fc2.weight True
# backbone.features.6.4.block.2.fc2.bias True
# backbone.features.6.4.block.3.0.weight True
# backbone.features.6.4.block.3.1.weight True
# backbone.features.6.4.block.3.1.bias True
# backbone.features.6.5.block.0.0.weight True
# backbone.features.6.5.block.0.1.weight True
# backbone.features.6.5.block.0.1.bias True
# backbone.features.6.5.block.1.0.weight True
# backbone.features.6.5.block.1.1.weight True
# backbone.features.6.5.block.1.1.bias True
# backbone.features.6.5.block.2.fc1.weight True
# backbone.features.6.5.block.2.fc1.bias True
# backbone.features.6.5.block.2.fc2.weight True
# backbone.features.6.5.block.2.fc2.bias True
# backbone.features.6.5.block.3.0.weight True
# backbone.features.6.5.block.3.1.weight True
# backbone.features.6.5.block.3.1.bias True
# backbone.features.6.6.block.0.0.weight True
# backbone.features.6.6.block.0.1.weight True
# backbone.features.6.6.block.0.1.bias True
# backbone.features.6.6.block.1.0.weight True
# backbone.features.6.6.block.1.1.weight True
# backbone.features.6.6.block.1.1.bias True
# backbone.features.6.6.block.2.fc1.weight True
# backbone.features.6.6.block.2.fc1.bias True
# backbone.features.6.6.block.2.fc2.weight True
# backbone.features.6.6.block.2.fc2.bias True
# backbone.features.6.6.block.3.0.weight True
# backbone.features.6.6.block.3.1.weight True
# backbone.features.6.6.block.3.1.bias True
# backbone.features.6.7.block.0.0.weight True
# backbone.features.6.7.block.0.1.weight True
# backbone.features.6.7.block.0.1.bias True
# backbone.features.6.7.block.1.0.weight True
# backbone.features.6.7.block.1.1.weight True
# backbone.features.6.7.block.1.1.bias True
# backbone.features.6.7.block.2.fc1.weight True
# backbone.features.6.7.block.2.fc1.bias True
# backbone.features.6.7.block.2.fc2.weight True
# backbone.features.6.7.block.2.fc2.bias True
# backbone.features.6.7.block.3.0.weight True
# backbone.features.6.7.block.3.1.weight True
# backbone.features.6.7.block.3.1.bias True
# backbone.features.6.8.block.0.0.weight True
# backbone.features.6.8.block.0.1.weight True
# backbone.features.6.8.block.0.1.bias True
# backbone.features.6.8.block.1.0.weight True
# backbone.features.6.8.block.1.1.weight True
# backbone.features.6.8.block.1.1.bias True
# backbone.features.6.8.block.2.fc1.weight True
# backbone.features.6.8.block.2.fc1.bias True
# backbone.features.6.8.block.2.fc2.weight True
# backbone.features.6.8.block.2.fc2.bias True
# backbone.features.6.8.block.3.0.weight True
# backbone.features.6.8.block.3.1.weight True
# backbone.features.6.8.block.3.1.bias True
# backbone.features.6.9.block.0.0.weight True
# backbone.features.6.9.block.0.1.weight True
# backbone.features.6.9.block.0.1.bias True
# backbone.features.6.9.block.1.0.weight True
# backbone.features.6.9.block.1.1.weight True
# backbone.features.6.9.block.1.1.bias True
# backbone.features.6.9.block.2.fc1.weight True
# backbone.features.6.9.block.2.fc1.bias True
# backbone.features.6.9.block.2.fc2.weight True
# backbone.features.6.9.block.2.fc2.bias True
# backbone.features.6.9.block.3.0.weight True
# backbone.features.6.9.block.3.1.weight True
# backbone.features.6.9.block.3.1.bias True
# backbone.features.6.10.block.0.0.weight True
# backbone.features.6.10.block.0.1.weight True
# backbone.features.6.10.block.0.1.bias True
# backbone.features.6.10.block.1.0.weight True
# backbone.features.6.10.block.1.1.weight True
# backbone.features.6.10.block.1.1.bias True
# backbone.features.6.10.block.2.fc1.weight True
# backbone.features.6.10.block.2.fc1.bias True
# backbone.features.6.10.block.2.fc2.weight True
# backbone.features.6.10.block.2.fc2.bias True
# backbone.features.6.10.block.3.0.weight True
# backbone.features.6.10.block.3.1.weight True
# backbone.features.6.10.block.3.1.bias True
# backbone.features.6.11.block.0.0.weight True
# backbone.features.6.11.block.0.1.weight True
# backbone.features.6.11.block.0.1.bias True
# backbone.features.6.11.block.1.0.weight True
# backbone.features.6.11.block.1.1.weight True
# backbone.features.6.11.block.1.1.bias True
# backbone.features.6.11.block.2.fc1.weight True
# backbone.features.6.11.block.2.fc1.bias True
# backbone.features.6.11.block.2.fc2.weight True
# backbone.features.6.11.block.2.fc2.bias True
# backbone.features.6.11.block.3.0.weight True
# backbone.features.6.11.block.3.1.weight True
# backbone.features.6.11.block.3.1.bias True
# backbone.features.6.12.block.0.0.weight True
# backbone.features.6.12.block.0.1.weight True
# backbone.features.6.12.block.0.1.bias True
# backbone.features.6.12.block.1.0.weight True
# backbone.features.6.12.block.1.1.weight True
# backbone.features.6.12.block.1.1.bias True
# backbone.features.6.12.block.2.fc1.weight True
# backbone.features.6.12.block.2.fc1.bias True
# backbone.features.6.12.block.2.fc2.weight True
# backbone.features.6.12.block.2.fc2.bias True
# backbone.features.6.12.block.3.0.weight True
# backbone.features.6.12.block.3.1.weight True
# backbone.features.6.12.block.3.1.bias True
# backbone.features.7.0.block.0.0.weight True
# backbone.features.7.0.block.0.1.weight True
# backbone.features.7.0.block.0.1.bias True
# backbone.features.7.0.block.1.0.weight True
# backbone.features.7.0.block.1.1.weight True
# backbone.features.7.0.block.1.1.bias True
# backbone.features.7.0.block.2.fc1.weight True
# backbone.features.7.0.block.2.fc1.bias True
# backbone.features.7.0.block.2.fc2.weight True
# backbone.features.7.0.block.2.fc2.bias True
# backbone.features.7.0.block.3.0.weight True
# backbone.features.7.0.block.3.1.weight True
# backbone.features.7.0.block.3.1.bias True
# backbone.features.7.1.block.0.0.weight True
# backbone.features.7.1.block.0.1.weight True
# backbone.features.7.1.block.0.1.bias True
# backbone.features.7.1.block.1.0.weight True
# backbone.features.7.1.block.1.1.weight True
# backbone.features.7.1.block.1.1.bias True
# backbone.features.7.1.block.2.fc1.weight True
# backbone.features.7.1.block.2.fc1.bias True
# backbone.features.7.1.block.2.fc2.weight True
# backbone.features.7.1.block.2.fc2.bias True
# backbone.features.7.1.block.3.0.weight True
# backbone.features.7.1.block.3.1.weight True
# backbone.features.7.1.block.3.1.bias True
# backbone.features.7.2.block.0.0.weight True
# backbone.features.7.2.block.0.1.weight True
# backbone.features.7.2.block.0.1.bias True
# backbone.features.7.2.block.1.0.weight True
# backbone.features.7.2.block.1.1.weight True
# backbone.features.7.2.block.1.1.bias True
# backbone.features.7.2.block.2.fc1.weight True
# backbone.features.7.2.block.2.fc1.bias True
# backbone.features.7.2.block.2.fc2.weight True
# backbone.features.7.2.block.2.fc2.bias True
# backbone.features.7.2.block.3.0.weight True
# backbone.features.7.2.block.3.1.weight True
# backbone.features.7.2.block.3.1.bias True
# backbone.features.7.3.block.0.0.weight True
# backbone.features.7.3.block.0.1.weight True
# backbone.features.7.3.block.0.1.bias True
# backbone.features.7.3.block.1.0.weight True
# backbone.features.7.3.block.1.1.weight True
# backbone.features.7.3.block.1.1.bias True
# backbone.features.7.3.block.2.fc1.weight True
# backbone.features.7.3.block.2.fc1.bias True
# backbone.features.7.3.block.2.fc2.weight True
# backbone.features.7.3.block.2.fc2.bias True
# backbone.features.7.3.block.3.0.weight True
# backbone.features.7.3.block.3.1.weight True
# backbone.features.7.3.block.3.1.bias True
# backbone.features.8.0.weight True
# backbone.features.8.1.weight True
# backbone.features.8.1.bias True
# backbone.classifier.1.weight True
# backbone.classifier.1.bias True

# %%
# ================================================================
# TRAINING LOOP
# ================================================================
for epoch in range(num_epochs):

    # ---------------- TRAIN ----------------
    model.train()
    train_loss = 0
    all_train_labels = []
    all_train_preds = []

    for images, labels in train_loader:
        images = images.to(DEVICE)
        labels = labels.float().to(DEVICE)

        optimizer.zero_grad()
        outputs = model(images).view(-1)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        preds = torch.sigmoid(outputs).round()
        all_train_labels.extend(labels.detach().cpu().numpy())
        all_train_preds.extend(preds.detach().cpu().numpy())

    avg_train_loss = train_loss / len(train_loader)
    train_acc = accuracy_score(all_train_labels, all_train_preds)

    # ---------------- VALIDATION ----------------
    model.eval()
    val_loss = 0
    all_val_labels = []
    all_val_preds = []
    

    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(DEVICE)
            labels = labels.float().to(DEVICE)

            outputs = model(images).view(-1)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            preds = torch.sigmoid(outputs).round()
            all_val_labels.extend(labels.cpu().numpy())
            all_val_preds.extend(preds.cpu().numpy())

    avg_val_loss = val_loss / len(val_loader)
    val_acc = accuracy_score(all_val_labels, all_val_preds)

    # ---------------- CHECKPOINT ----------------
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        epochs_no_improve = 0
        torch.save(model.state_dict(), best_model_path)
        print(f"Best model saved at: {best_model_path}")
    else:
        epochs_no_improve += 1

    print(
        f"Epoch {epoch+1}/{num_epochs} | "
        f"Train Loss: {avg_train_loss:.4f}, Acc: {train_acc:.4f} | "
        f"Val Loss: {avg_val_loss:.4f}, Acc: {val_acc:.4f}"
    )

    if epochs_no_improve >= patience:
        print("Early stopping triggered.")
        break

# ================================================================
# LOAD BEST MODEL
# ================================================================
model.load_state_dict(torch.load(best_model_path))
print("Best model loaded")
# Out:
# Best model saved at: best_model_efficientnet_b7.pth
# Epoch 1/200 | Train Loss: 0.5465, Acc: 0.6926 | Val Loss: 0.4216, Acc: 0.8193
# Best model saved at: best_model_efficientnet_b7.pth
# Epoch 2/200 | Train Loss: 0.2950, Acc: 0.8724 | Val Loss: 0.2053, Acc: 0.9167
# Best model saved at: best_model_efficientnet_b7.pth
# Epoch 3/200 | Train Loss: 0.1853, Acc: 0.9274 | Val Loss: 0.1680, Acc: 0.9313
# Epoch 4/200 | Train Loss: 0.1322, Acc: 0.9497 | Val Loss: 0.1850, Acc: 0.9313
# Best model saved at: best_model_efficientnet_b7.pth
# Epoch 107/200 | Train Loss: 0.0080, Acc: 0.9973 | Val Loss: 0.0634, Acc: 0.9847
# Epoch 108/200 | Train Loss: 0.0070, Acc: 0.9980 | Val Loss: 0.0756, Acc: 0.9773
# Epoch 109/200 | Train Loss: 0.0050, Acc: 0.9986 | Val Loss: 0.0599, Acc: 0.9840
# Epoch 110/200 | Train Loss: 0.0105, Acc: 0.9977 | Val Loss: 0.0724, Acc: 0.9820
# Epoch 111/200 | Train Loss: 0.0037, Acc: 0.9991 | Val Loss: 0.1069, Acc: 0.9747
# Epoch 112/200 | Train Loss: 0.0077, Acc: 0.9974 | Val Loss: 0.0731, Acc: 0.9833
# Epoch 113/200 | Train Loss: 0.0077, Acc: 0.9973 | Val Loss: 0.0529, Acc: 0.9847
# Epoch 114/200 | Train Loss: 0.0020, Acc: 0.9990 | Val Loss: 0.0865, Acc: 0.9807
# Epoch 115/200 | Train Loss: 0.0109, Acc: 0.9966 | Val Loss: 0.0499, Acc: 0.9873
# Epoch 116/200 | Train Loss: 0.0060, Acc: 0.9983 | Val Loss: 0.0664, Acc: 0.9840
# Epoch 117/200 | Train Loss: 0.0015, Acc: 0.9994 | Val Loss: 0.0592, Acc: 0.9873
# Epoch 118/200 | Train Loss: 0.0014, Acc: 0.9996 | Val Loss: 0.0896, Acc: 0.9787
# Epoch 119/200 | Train Loss: 0.0057, Acc: 0.9986 | Val Loss: 0.0670, Acc: 0.9880
# Epoch 120/200 | Train Loss: 0.0050, Acc: 0.9983 | Val Loss: 0.0609, Acc: 0.9833
# Epoch 121/200 | Train Loss: 0.0102, Acc: 0.9971 | Val Loss: 0.0520, Acc: 0.9860
# Early stopping triggered.
# Best model loaded

# %%
# ================================================================
# TEST EVALUATION
# ================================================================
model.eval()
all_labels = []
all_preds = []
all_probs = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(DEVICE)
        labels = labels.to(DEVICE)

        outputs = model(images).view(-1)
        probs = torch.sigmoid(outputs)
        preds = (probs > 0.5).float()

        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())


# =================== METRICS ===================
precision = precision_score(all_labels, all_preds)
recall    = recall_score(all_labels, all_preds)
f1        = f1_score(all_labels, all_preds)
accuracy  = accuracy_score(all_labels, all_preds)
auroc = roc_auc_score(all_labels, all_probs)

print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")

# Classification report
report = classification_report(all_labels, all_preds, digits=4)
print("Classification Report:\n", report)

# Confusion matrix
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Real", "Fake"])

disp.plot(cmap='Blues', values_format='d')
plt.title("Confusion Matrix")
plt.show()

# ROC Curve
fpr, tpr, thresholds = roc_curve(all_labels, all_probs)
plt.plot(fpr, tpr, label=f'AUC = {auroc:.4f}')
plt.plot([0,1], [0,1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend(loc="lower right")
plt.show()
# Out:
# Accuracy:  0.9807
# Precision: 0.9814
# Recall:    0.9801
# F1 Score:  0.9808
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.9799    0.9812    0.9806       746
#            1     0.9814    0.9801    0.9808       754
#
#     accuracy                         0.9807      1500
#    macro avg     0.9807    0.9807    0.9807      1500
# weighted avg     0.9807    0.9807    0.9807      1500
